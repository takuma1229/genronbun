# %% [markdown]
# ## 演習問題 2.7

# %%
import re, collections

def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

def merge_vocab(pair, v_in):
    v_out = {}
    bigram = ' '.join(pair) # 空白が入っており、もとのvocabの形式と合っていることに注意
    replacement = ''.join(pair)
    pattern = re.compile(r'(?<!\S)' + re.escape(bigram) + r'(?!\S)')
    print(f"pattern: {pattern}")
    for word in v_in:
        w_out = pattern.sub(replacement, word) # 元のvocabの"e s"みたいな部分を"es"で置換する
        print(f"w_out: {w_out}")
        v_out[w_out] = v_in[word]
    return v_out

vocab = {
    'l o w </w>': 5,
    'l o w e r </w>': 2,
    'n e w e s t </w>': 6,
    'w i d e s t </w>': 3,
}

num_merges = 10
for i in range(num_merges):
    pairs = get_stats(vocab)
    print("\npairs")
    print(pairs)
    best = max(pairs, key=pairs.get)
    print("\nbest")
    print(best)
    vocab = merge_vocab(best, vocab)
    print("\nvocab")
    print(vocab)
# Out:
# pairs
# defaultdict(<class 'int'>, {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 8, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('e', 's'): 9, ('s', 't'): 9, ('t', '</w>'): 9, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'e'): 3})
#
# best
# ('e', 's')
# pattern: re.compile('(?<!\\S)e\\ s(?!\\S)')
# w_out: l o w </w>
# w_out: l o w e r </w>
# w_out: n e w es t </w>
# w_out: w i d es t </w>
#
# vocab
# {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w es t </w>': 6, 'w i d es t </w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('w', 'es'): 6, ('es', 't'): 9, ('t', '</w>'): 9, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'es'): 3})
#
# best
# ('es', 't')
# pattern: re.compile('(?<!\\S)es\\ t(?!\\S)')
# w_out: l o w </w>
# w_out: l o w e r </w>
# w_out: n e w est </w>
# w_out: w i d est </w>
#
# vocab
# {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w est </w>': 6, 'w i d est </w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('w', 'est'): 6, ('est', '</w>'): 9, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est'): 3})
#
# best
# ('est', '</w>')
# pattern: re.compile('(?<!\\S)est\\ </w>(?!\\S)')
# w_out: l o w </w>
# w_out: l o w e r </w>
# w_out: n e w est</w>
# w_out: w i d est</w>
#
# vocab
# {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w est</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('w', 'est</w>'): 6, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('l', 'o')
# pattern: re.compile('(?<!\\S)l\\ o(?!\\S)')
# w_out: lo w </w>
# w_out: lo w e r </w>
# w_out: n e w est</w>
# w_out: w i d est</w>
#
# vocab
# {'lo w </w>': 5, 'lo w e r </w>': 2, 'n e w est</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('lo', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('w', 'est</w>'): 6, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('lo', 'w')
# pattern: re.compile('(?<!\\S)lo\\ w(?!\\S)')
# w_out: low </w>
# w_out: low e r </w>
# w_out: n e w est</w>
# w_out: w i d est</w>
#
# vocab
# {'low </w>': 5, 'low e r </w>': 2, 'n e w est</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('low', '</w>'): 5, ('low', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('w', 'est</w>'): 6, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('n', 'e')
# pattern: re.compile('(?<!\\S)n\\ e(?!\\S)')
# w_out: low </w>
# w_out: low e r </w>
# w_out: ne w est</w>
# w_out: w i d est</w>
#
# vocab
# {'low </w>': 5, 'low e r </w>': 2, 'ne w est</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('low', '</w>'): 5, ('low', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('ne', 'w'): 6, ('w', 'est</w>'): 6, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('ne', 'w')
# pattern: re.compile('(?<!\\S)ne\\ w(?!\\S)')
# w_out: low </w>
# w_out: low e r </w>
# w_out: new est</w>
# w_out: w i d est</w>
#
# vocab
# {'low </w>': 5, 'low e r </w>': 2, 'new est</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('low', '</w>'): 5, ('low', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('new', 'est</w>'): 6, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('new', 'est</w>')
# pattern: re.compile('(?<!\\S)new\\ est</w>(?!\\S)')
# w_out: low </w>
# w_out: low e r </w>
# w_out: newest</w>
# w_out: w i d est</w>
#
# vocab
# {'low </w>': 5, 'low e r </w>': 2, 'newest</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('low', '</w>'): 5, ('low', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('low', '</w>')
# pattern: re.compile('(?<!\\S)low\\ </w>(?!\\S)')
# w_out: low</w>
# w_out: low e r </w>
# w_out: newest</w>
# w_out: w i d est</w>
#
# vocab
# {'low</w>': 5, 'low e r </w>': 2, 'newest</w>': 6, 'w i d est</w>': 3}
#
# pairs
# defaultdict(<class 'int'>, {('low', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'est</w>'): 3})
#
# best
# ('w', 'i')
# pattern: re.compile('(?<!\\S)w\\ i(?!\\S)')
# w_out: low</w>
# w_out: low e r </w>
# w_out: newest</w>
# w_out: wi d est</w>
#
# vocab
# {'low</w>': 5, 'low e r </w>': 2, 'newest</w>': 6, 'wi d est</w>': 3}
